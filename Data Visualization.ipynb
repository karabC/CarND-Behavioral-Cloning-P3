# %%
import csv
import cv2
import numpy as np
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


# %matplotlib inline

lines = []
with open('./data/driving_log.csv') as csvFile:
	reader = csv.reader(csvFile)
	for line in reader:
		lines.append(line)
lines.pop(0)
# Out:
# ['center', 'left', 'right', 'steering', 'throttle', 'brake', 'speed']

# %%
def loadImage(source_path):
	filename = source_path.split('/')[-1]
	current_path = './data/IMG/' + filename
	imageBGR =cv2.imread(current_path)
	return imageBGR

# %%
img = loadImage(lines[0][0])
croppedImg = img[25:90,:,:]

# %%
plt.imshow(img)

# %%
plt.imshow(croppedImg)

# %%
left_img = loadImage(lines[0][1])
right_img = loadImage(lines[0][2])
croppedLeftImg = left_img[25:90,:,:]
croppedRightImg = right_img[25:90,:,:]

# %%
plt.imshow(croppedLeftImg)

# %%
plt.imshow(croppedRightImg)

# %%
flipped = cv2.flip(img, 1)
plt.imshow(flipped)
